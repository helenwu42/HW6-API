# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from config import weather_key
from config import gkey

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities, and countries
lat_lngs = []
cities = []
countries = []
la = []
long = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    country = citipy.nearest_city(lat_lng[0], lat_lng[1]).country_code

    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        countries.append(country)
        la.append(lat_lng[0])
        long.append(lat_lng[1])
        
        
       


# Create a dataframe 
cities_pd = pd.DataFrame({"City" : cities})


cities_pd["Cloudiness"] = ""
cities_pd["Country"] = countries
cities_pd["Date"] = ""
cities_pd["Humidity"] = ""
cities_pd["Lat"] = la
cities_pd["Lng"] = long
cities_pd["Max Temp"] = ""
cities_pd["Wind Speed"] = ""
# Out:
#                          City Cloudiness Country Date Humidity        Lat  \
# 0                       bluff                 nz               -77.289149
# 1                   saskylakh                 ru                77.920890
# 2                      faanui                 pf               -15.869032
# 3                      albany                 au               -63.379017
# 4                   hithadhoo                 mv               -14.896128
# 5                   taolanaro                 mg               -70.323263
# 6                     labuhan                 id                -7.394236
# 7                      iberia                 pe               -11.592860
# 8                   busselton                 au               -75.154836
# 9                  chokurdakh                 ru                71.698788
# 10                     castro                 cl               -43.563946
# 11                   cururupu                 br                 6.785602
# 12                      kapaa                 us                21.619125
# 13                    ushuaia                 ar               -54.620075
# 14                   necochea                 ar               -46.328139
# 15                       hilo                 us                 3.635736
# 16                  quelimane                 mz               -17.259746
# 17                    mataura                 pf               -73.728758
# 18                   klaksvik                 fo                80.391713
# 19                  cape town                 za               -52.006703
# 20                   khatanga                 ru                77.736368
# 21                pangnirtung                 ca                67.733488
# 22                    guozhen                 cn                35.026711
# 23                 el balyana                 eg                26.011395
# 24                  jamestown                 sh               -17.123594
# 25             severo-kurilsk                 ru                47.549008
# 26                       lebu                 cl               -36.147623
# 27                       lata                 sb                -5.756910
# 28                new norfolk                 au               -49.804289
# 29                   tsihombe                 mg               -45.126898
# ..                        ...        ...     ...  ...      ...        ...
# 610                  udachnyy                 ru                68.889343
# 611                     muros                 es                45.548924
# 612                balkanabat                 tm                38.843149
# 613                    nongan                 cn                44.231559
# 614                     zarya                 ru                60.110515
# 615                   phalodi                 in                27.602551
# 616                      brae                 gb                62.601405
# 617               otjimbingwe                 na               -23.334081
# 618                    mardin                 tr                36.604401
# 619                   namwala                 zm               -15.354559
# 620                      tura                 ru                69.125487
# 621              kruisfontein                 za               -48.572334
# 622                ballinrobe                 ie                53.670380
# 623                   midland                 us                44.541332
# 624                    kavali                 in                14.977064
# 625                     opuwo                 na               -17.577458
# 626                    sabang                 id                 7.304693
# 627            jefferson city                 us                38.321409
# 628                 iranshahr                 ir                26.643353
# 629                   kajaani                 fi                63.796224
# 630                     ihosy                 mg               -23.140505
# 631                  huangmei                 cn                30.759053
# 632                  chochola                 mx                20.676922
# 633                    kalabo                 zm               -15.493734
# 634                     muzhi                 ru                65.402396
# 635                 loa janan                 id                -0.766812
# 636                   northam                 au               -27.433741
# 637  sao gabriel da cachoeira                 br                 1.175453
# 638                     utica                 us                43.390278
# 639                      daru                 pg               -10.100063
#
#             Lng Max Temp Wind Speed
# 0    152.914566
# 1    116.109621
# 2   -154.089523
# 3    124.617824
# 4     72.494024
# 5     69.514934
# 6    105.390883
# 7    -70.019403
# 8     93.637250
# 9    147.149528
# 10   -82.090699
# 11   -40.745929
# 12  -174.532215
# 13   -69.193349
# 14   -55.344960
# 15  -149.726374
# 16    37.361910
# 17  -163.211383
# 18    -3.967842
# 19    -5.400322
# 20   103.237817
# 21   -66.837740
# 22   107.202095
# 23    31.845676
# 24    -7.661052
# 25   156.813198
# 26  -100.381555
# 27   169.274544
# 28   142.386380
# 29    45.484391
# ..          ...      ...        ...
# 610  112.392531
# 611  -12.497546
# 612   53.227356
# 613  125.071893
# 614   48.124926
# 615   72.610561
# 616   -2.879861
# 617   15.851739
# 618   40.635044
# 619   25.940932
# 620   96.579064
# 621   24.977453
# 622   -9.392470
# 623  -84.480520
# 624   80.404519
# 625   13.312440
# 626   95.855090
# 627  -92.496238
# 628   60.985391
# 629   27.976252
# 630   45.495738
# 631  116.236801
# 632  -89.736394
# 633   20.738998
# 634   62.806033
# 635  117.001250
# 636  121.155847
# 637  -65.884391
# 638  -74.882903
# 639  143.225459
#
# [640 rows x 9 columns]

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

cloud = []
date = []
humidity = []
maxTep = []
wind = []


# Build partial query URL
query_url = f"{url}appid={weather_key}&units={units}&q="

print("Beginning Data Retrieval")
print("--------------------------------")
for index, row in cities_pd.iterrows():
    
    city = row['City']
    response = requests.get(query_url + city).json()
    
    if response["cod"] == "404":
        print("City not found, skipping...")

    else:
        cities_pd.set_value(index, "Cloudiness", response["clouds"]["all"])
        cities_pd.set_value(index, "Date", response["dt"])
        cities_pd.set_value(index, "Humidity", response["main"]["humidity"])
        cities_pd.set_value(index, "Max Temp", response["main"]["temp_max"])
        cities_pd.set_value(index, "Wind Speed", response["wind"]["speed"])
        
        print("Processing record " + str(index) + " of Set 1 | " + city )
        print(query_url + city)
    
cities_pd
# Out:
# Beginning Data Retrieval
# --------------------------------
# C:\Users\helen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:26: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\helen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:27: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\helen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:28: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\helen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:29: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\helen\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:30: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing record 0 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=bluff
# Processing record 1 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=saskylakh
# Processing record 2 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=faanui
# Processing record 3 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=albany
# Processing record 4 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=hithadhoo
# City not found, skipping...
# Processing record 6 of Set 1 | labuhan
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=labuhan
# Processing record 7 of Set 1 | iberia
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=iberia
# Processing record 8 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=busselton
# Processing record 9 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=chokurdakh
# Processing record 10 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=castro
# Processing record 11 of Set 1 | cururupu
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=cururupu
# Processing record 12 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=kapaa
# Processing record 13 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=ushuaia
# Processing record 14 of Set 1 | necochea
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=necochea
# Processing record 15 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=hilo
# Processing record 16 of Set 1 | quelimane
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=quelimane
# Processing record 17 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=mataura
# Processing record 18 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=klaksvik
# Processing record 19 of Set 1 | cape town
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=cape town
# Processing record 20 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=khatanga
# Processing record 21 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=pangnirtung
# Processing record 22 of Set 1 | guozhen
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=guozhen
# City not found, skipping...
# Processing record 24 of Set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=jamestown
# Processing record 25 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=severo-kurilsk
# Processing record 26 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=lebu
# Processing record 27 of Set 1 | lata
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=lata
# Processing record 28 of Set 1 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=new norfolk
# City not found, skipping...
# Processing record 30 of Set 1 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=praia da vitoria
# Processing record 31 of Set 1 | luwuk
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=luwuk
# Processing record 32 of Set 1 | mpongwe
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=mpongwe
# Processing record 33 of Set 1 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=carnarvon
# Processing record 34 of Set 1 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=leningradskiy
# Processing record 35 of Set 1 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=port lincoln
# Processing record 36 of Set 1 | hambantota
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=hambantota
# Processing record 37 of Set 1 | kodiak
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=kodiak
# Processing record 38 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=punta arenas
# Processing record 39 of Set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=vila franca do campo
# Processing record 40 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=barrow
# Processing record 41 of Set 1 | ustye
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=ustye
# Processing record 42 of Set 1 | shush
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=shush
# Processing record 43 of Set 1 | tarakan
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=tarakan
# City not found, skipping...
# Processing record 45 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=rikitea
# Processing record 46 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=cherskiy
# Processing record 47 of Set 1 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=ilulissat
# Processing record 48 of Set 1 | moorhead
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=moorhead
# Processing record 49 of Set 1 | atambua
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=atambua
# Processing record 50 of Set 1 | santa marta
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=santa marta
# Processing record 51 of Set 1 | georgetown
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=georgetown
# Processing record 52 of Set 1 | cabra
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=cabra
# Processing record 53 of Set 1 | lyubim
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=lyubim
# Processing record 54 of Set 1 | galveston
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=galveston
# City not found, skipping...
# City not found, skipping...
# Processing record 57 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=qaanaaq
# Processing record 58 of Set 1 | san vicente
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=san vicente
# Processing record 59 of Set 1 | nandyal
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=nandyal
# Processing record 60 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=hermanus
# Processing record 61 of Set 1 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=tasiilaq
# Processing record 62 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=bethel
# Processing record 63 of Set 1 | faya
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=faya
# Processing record 64 of Set 1 | shonguy
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=shonguy
# City not found, skipping...
# City not found, skipping...
# Processing record 67 of Set 1 | gananoque
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=gananoque
# Processing record 68 of Set 1 | omboue
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=omboue
# Processing record 69 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=yellowknife
# Processing record 70 of Set 1 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=taoudenni
# Processing record 71 of Set 1 | tigzirt
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=tigzirt
# City not found, skipping...
# Processing record 73 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=atuona
# Processing record 74 of Set 1 | birnin kebbi
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=birnin kebbi
# Processing record 75 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=bredasdorp
# Processing record 76 of Set 1 | maine-soroa
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=maine-soroa
# Processing record 77 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=lagoa
# Processing record 78 of Set 1 | port alfred
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=port alfred
# Processing record 79 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=saint george
# Processing record 80 of Set 1 | zeya
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=zeya
# Processing record 81 of Set 1 | shambu
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=shambu
# Processing record 82 of Set 1 | hovd
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=hovd
# Processing record 83 of Set 1 | palmer
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=palmer
# Processing record 84 of Set 1 | thompson
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=thompson
# Processing record 85 of Set 1 | caravelas
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=caravelas
# Processing record 86 of Set 1 | henties bay
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=henties bay
# Processing record 87 of Set 1 | bugaan
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=bugaan
# City not found, skipping...
# Processing record 89 of Set 1 | luderitz
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=luderitz
# Processing record 90 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=geraldton
# Processing record 91 of Set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=hobart
# Processing record 92 of Set 1 | maniitsoq
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=maniitsoq
# City not found, skipping...
# Processing record 94 of Set 1 | sorland
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=sorland
# Processing record 95 of Set 1 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=marsh harbour
# Processing record 96 of Set 1 | akalgarh
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=akalgarh
# Processing record 97 of Set 1 | along
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=along
# Processing record 98 of Set 1 | agadez
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=agadez
# Processing record 99 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=vaini
# Processing record 100 of Set 1 | manga
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=manga
# Processing record 101 of Set 1 | quatre cocos
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=quatre cocos
# Processing record 102 of Set 1 | nome
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=nome
# Processing record 103 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?appid=cf98d17636303048969cb8d8107e3831&units=Imperial&q=fortuna
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c4e79c123752> in <module>()
#      18
#      19     city = row['City']
# ---> 20     response = requests.get(query_url + city).json()
#      21
#      22     if response["cod"] == "404":
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
